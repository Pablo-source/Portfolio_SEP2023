# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Plotly is Python open source graphical library, used to produce different types of plots: line plots, area charts, bar charts, error bars box plots and histograms

# %% [markdown]
# Matplotlib is a plotting library for the Python proggrammming language and its numerical mathematics extension NumPy. It provider an object-oriented API for embedding plots into applications

# %% [markdown]
# ### 1. Load required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 2. Change workind directory

# %%
## Get my working directory
import os
path = os.getcwd()
path
# Out:
# 'C:\\Pablo UK\\46 DATA SCIENCE all\\44 Python'

# %%
os.chdir('C:/Pablo UK/46 DATA SCIENCE all/44 Python')

# %%
os.getcwd()
# Out:
# 'C:\\Pablo UK\\46 DATA SCIENCE all\\44 Python'

# %% [markdown]
# ### 3. Load housing dataset

# %% [markdown]
# We have worked in the past with Airlines open source dataset. Today we will use the Housing price dataset in San Francisco bay area

# %%
# PASSENGER DATASET. Load csv file 
Dataset = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv')

# %%
# Housing DATA 
Housedata = pd.read_csv('https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv')

# %%
# Check dataset structure
Housedata.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Import required matplotlib library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Image result for matplotlib inline meaning
# %matplotlib inline sets the backend of matplotlib to the 'inline' backend: With this backend, the output of plotting commands is displayed inline within frontends like the Jupyter notebook, directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.

# %%
Housedata.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# We can start by displaying a histogram for each numerical attribute

# %%
Housedata.hist(bins=50,figsize=(20,15))
plt.show()

# %% [markdown]
# Split into train and test data sets

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# We can use this function to split into train test and to introduce a radom generator seed

# %%
train_set, test_set = train_test_split(Housedata,test_size=0.2,random_state=42)

# %% [markdown]
# Check how the split has worked on the original dataset

# %%
len(Housedata)
# Out:
# 20640

# %%
len(train_set)
# Out:
# 16512

# %%
len(test_set)
# Out:
# 4128

# %%
In this workbook we will explore how to produce plots using plotly library

# %% [markdown]
# ### 4. Plots

# %% [markdown]
# #### 4.1 Scatter plots

# %%
train_plots = train_set.copy()

# %%
train_plots.plot(kind="scatter", x="longitude",y="latitude")

# %%
train_plots.plot(kind="scatter", x="longitude",y="latitude")

# %% [markdown]
# #### 4.2 Line plots

# %%
os.chdir('C:/Pablo UK/46 DATA SCIENCE all/44 Python')

# %%
# Topics covered in Plotly
- drawing a plot
- adding a title
- adding/changing axis
- x and y  labels
- different types of plots (scatter, bar, l;ine) 
- MULTIPOLE LINES ON SAME PLOT
- LEGENDS
- How to define plt size

# %%
# Load data from a Renting Bikes company in Seattle
# Bikes renting business in Seattle.  Load csv file
Bikes_Daily = pd.read_csv('Daily_bikes.csv')

# %%
Bikes_Daily.head()
# Out:
#    Unnamed: 0        date  Nbikes
# 0           1  2011-01-01     985
# 1           2  2011-01-02     801
# 2           3  2011-01-03    1349
# 3           4  2011-01-04    1562
# 4           5  2011-01-05    1600

# %%
Bikes = Bikes_Daily[['date','Nbikes']]

# %%
Bikes['Period'] = pd.to_datetime(Bikes['date'])

# %%
Bikes_prep = Bikes[['Period','Nbikes']]

# %%
Bikes_dataset = Bikes_prep.set_index('Period')

# %%
Bikes_dataset.head()
# Out:
#             Nbikes
# Period
# 2011-01-01     985
# 2011-01-02     801
# 2011-01-03    1349
# 2011-01-04    1562
# 2011-01-05    1600

# %%
plt.figure(figsize=(15,6))
plt.plot(Bikes_dataset,label="Bikes Sales")

# %% [markdown]
# Then we can add a title to it

# %%
plt.figure(figsize=(15,6))
plt.title('Total bikes admissions')
plt.plot(Bikes_dataset,label="Bikes Sales")
#plt.ylabel("value")
#plt.xlabel("days")
#plt.show()

# %% [markdown]
# Now we can add legends to it

# %%
plt.figure(figsize=(15,6))
plt.title('Total bikes admissions')
plt.plot(Bikes_dataset,label="Bikes Sales")
plt.legend()

# %% [markdown]
# We can also add X and Y axis labels

# %%
plt.figure(figsize=(15,6))
plt.title('Total bikes admissions')
plt.plot(Bikes_dataset,label="Bikes Sales")
plt.ylabel("value")
plt.xlabel("days")
plt.show()

# %% [markdown]
# #### 4.3 Multiple Line plots

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %% [markdown]
# #### 4.3 Bar plots

# %% [markdown]
# #### 4.3.2 Vertical Bar plots

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### 4.3.2 Combining plots together: barplot, scatter and line plots

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# #### 4.3.2 Horizontal Bar plots

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %% [markdown]
# Change plot marks in a defined lpot. We use letters 'r' pr 'bs' or 'g' to change the mark

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
